# %% [markdown]
# ### EDA and Data Lookup

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Portfolio-Projects\Job-Description-Analysis\data\raw\Job_descriptions_v2.csv")
df.head(5)
# Out:
#    Unnamed: 0  id         role        type  \
# 0           0   1  AI Engineer  Internship
# 1           1   2  AI Engineer  Internship
# 2           2   3  AI Engineer  Internship
# 3           3   4  AI Engineer      Senior
# 4           4   5  AI Engineer      Junior
#
#                                             job_desc  year qualification  \
# 0  Final year students / recent graduates in CS, ...  2026     Bachelors
# 1  Proficiency in Python and comfort working with...  2026     Bachelors
# 2  Strong interest in AI and a willingness to lea...  2026     Bachelors
# 3  6+ years full-stack software engineering exper...  2026           NaN
# 4  AI/ML models, Python, Core ML concepts, ML fra...  2026     Bachelors
#
#   experience                                        tech_skills  \
# 0          0    Python, ML, LangChain, Hugging Face, OpenAI API
# 1          0  Python, APIs, LLMs, Prompt Engineering, LangCh...
# 2          0  Python, Javascript, React, Full Stack, APIs, M...
# ...

# %% [markdown]
# ### EDA

# %%
df.isna().count()
# Out:
# Unnamed: 0       747
# id               747
# role             747
# type             747
# job_desc         747
# year             747
# qualification    747
# experience       747
# tech_skills      747
# soft_skills      747
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0          id         year
# count  747.000000  747.000000   747.000000
# mean   381.730924  382.730924  2025.967871
# std    223.715814  223.715814     0.435103
# min      0.000000    1.000000  2018.000000
# 25%    186.500000  187.500000  2026.000000
# 50%    382.000000  383.000000  2026.000000
# 75%    573.500000  574.500000  2026.000000
# max    768.000000  769.000000  2026.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 747 entries, 0 to 746
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     747 non-null    int64
#  1   id             747 non-null    int64
#  2   role           747 non-null    str
#  3   type           747 non-null    str
#  4   job_desc       747 non-null    str
#  5   year           747 non-null    int64
#  6   qualification  632 non-null    str
#  7   experience     747 non-null    str
#  8   tech_skills    747 non-null    str
#  9   soft_skills    747 non-null    str
# dtypes: int64(3), str(7)
# memory usage: 58.5 KB

# %%
df.fillna('Not Specified', inplace=True).head(5)
# Out:
#    Unnamed: 0  id         role        type  \
# 0           0   1  AI Engineer  Internship
# 1           1   2  AI Engineer  Internship
# 2           2   3  AI Engineer  Internship
# 3           3   4  AI Engineer      Senior
# 4           4   5  AI Engineer      Junior
#
#                                             job_desc  year  qualification  \
# 0  Final year students / recent graduates in CS, ...  2026      Bachelors
# 1  Proficiency in Python and comfort working with...  2026      Bachelors
# 2  Strong interest in AI and a willingness to lea...  2026      Bachelors
# 3  6+ years full-stack software engineering exper...  2026  Not Specified
# 4  AI/ML models, Python, Core ML concepts, ML fra...  2026      Bachelors
#
#   experience                                        tech_skills  \
# 0          0    Python, ML, LangChain, Hugging Face, OpenAI API
# 1          0  Python, APIs, LLMs, Prompt Engineering, LangCh...
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0       747
# id               747
# role               8
# type               3
# job_desc         747
# year               4
# qualification      4
# experience        58
# tech_skills      652
# soft_skills       80
# dtype: int64

# %%
role_unique = df['role'].unique()
print(role_unique)
# Out:
# <StringArray>
# [       'AI Engineer',       'AI Developer',  'Software Engineer',
#  'Software Developer',     'Cloud Engineer',    'Cloud Architect',
#      'Data Scientist',       'Data Analyst']
# Length: 8, dtype: str

# %%
type_unique = df['type'].unique()
print(type_unique)
# Out:
# <StringArray>
# ['Internship', 'Senior', 'Junior']
# Length: 3, dtype: str

# %%
experience_unique = df['experience'].unique()
print(experience_unique)
# Out:
# <StringArray>
# [                                                                                                                                                      '0',
#                                                                                                                                                     '5-10',
#                                                                                                                                                      '0-1',
#                                                                                                                                                      '1-5',
#                                                                                                                                                      '15+',
#                                                                                                                                                    '10-15',
# ...

# %%
df.to_csv("C:\\Portfolio-Projects\\Job-Description-Analysis\\data\\clean\\v2\\cleaned_job_descriptions_v2.csv", index=False)
