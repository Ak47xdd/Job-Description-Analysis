# %% [markdown]
# ### Data Engineering

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Portfolio-Projects\Job-Description-Analysis\data\clean\v2\cleaned_job_descriptions_v2.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0  id         role        type  \
# 0           0   1  AI Engineer  Internship
# 1           1   2  AI Engineer  Internship
# 2           2   3  AI Engineer  Internship
# 3           3   4  AI Engineer      Senior
# 4           4   5  AI Engineer      Junior
# 5           5   6  AI Engineer      Junior
# 6           6   7  AI Engineer      Senior
# 7           7   8  AI Engineer      Junior
# 8           8   9  AI Engineer  Internship
# 9           9  10  AI Engineer  Internship
#
#                                             job_desc  year  qualification  \
# 0  Final year students / recent graduates in CS, ...  2026      Bachelors
# 1  Proficiency in Python and comfort working with...  2026      Bachelors
# 2  Strong interest in AI and a willingness to lea...  2026      Bachelors
# 3  6+ years full-stack software engineering exper...  2026  Not Specified
# 4  AI/ML models, Python, Core ML concepts, ML fra...  2026      Bachelors
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 747 entries, 0 to 746
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     747 non-null    int64
#  1   id             747 non-null    int64
#  2   role           747 non-null    str
#  3   type           747 non-null    str
#  4   job_desc       747 non-null    str
#  5   year           747 non-null    int64
#  6   qualification  747 non-null    str
#  7   experience     747 non-null    str
#  8   tech_skills    747 non-null    str
#  9   soft_skills    747 non-null    str
# dtypes: int64(3), str(7)
# memory usage: 58.5 KB

# %%
df_intern = df[df['type'].eq('Internship')]
df_intern.head(10)
# Out:
#     Unnamed: 0  id          role        type  \
# 0            0   1   AI Engineer  Internship
# 1            1   2   AI Engineer  Internship
# 2            2   3   AI Engineer  Internship
# 8            8   9   AI Engineer  Internship
# 9            9  10   AI Engineer  Internship
# 12          12  13  AI Developer  Internship
# 24          24  25   AI Engineer  Internship
# 25          25  26   AI Engineer  Internship
# 26          26  27   AI Engineer  Internship
# 27          27  28   AI Engineer  Internship
#
#                                              job_desc  year qualification  \
# 0   Final year students / recent graduates in CS, ...  2026     Bachelors
# 1   Proficiency in Python and comfort working with...  2026     Bachelors
# 2   Strong interest in AI and a willingness to lea...  2026     Bachelors
# 8   Python\r\nMachine Learning Fundamentals\r\nLar...  2026     Bachelors
# 9   Solid understanding of LLMs, tokenization, tra...  2026     Bachelors
# ...

# %%
df_intern.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 101 entries, 0 to 744
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     101 non-null    int64
#  1   id             101 non-null    int64
#  2   role           101 non-null    str
#  3   type           101 non-null    str
#  4   job_desc       101 non-null    str
#  5   year           101 non-null    int64
#  6   qualification  101 non-null    str
#  7   experience     101 non-null    str
#  8   tech_skills    101 non-null    str
#  9   soft_skills    101 non-null    str
# dtypes: int64(3), str(7)
# memory usage: 8.7 KB

# %%
df_intern = df_intern[df_intern['qualification'].eq('Bachelors')]
df_intern.head(10)
# Out:
#     Unnamed: 0  id          role        type  \
# 0            0   1   AI Engineer  Internship
# 1            1   2   AI Engineer  Internship
# 2            2   3   AI Engineer  Internship
# 8            8   9   AI Engineer  Internship
# 9            9  10   AI Engineer  Internship
# 12          12  13  AI Developer  Internship
# 24          24  25   AI Engineer  Internship
# 25          25  26   AI Engineer  Internship
# 26          26  27   AI Engineer  Internship
# 27          27  28   AI Engineer  Internship
#
#                                              job_desc  year qualification  \
# 0   Final year students / recent graduates in CS, ...  2026     Bachelors
# 1   Proficiency in Python and comfort working with...  2026     Bachelors
# 2   Strong interest in AI and a willingness to lea...  2026     Bachelors
# 8   Python\r\nMachine Learning Fundamentals\r\nLar...  2026     Bachelors
# 9   Solid understanding of LLMs, tokenization, tra...  2026     Bachelors
# ...

# %%
df_intern.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 96 entries, 0 to 744
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     96 non-null     int64
#  1   id             96 non-null     int64
#  2   role           96 non-null     str
#  3   type           96 non-null     str
#  4   job_desc       96 non-null     str
#  5   year           96 non-null     int64
#  6   qualification  96 non-null     str
#  7   experience     96 non-null     str
#  8   tech_skills    96 non-null     str
#  9   soft_skills    96 non-null     str
# dtypes: int64(3), str(7)
# memory usage: 8.2 KB

# %%
df_intern.to_csv(r"C:\Portfolio-Projects\Job-Description-Analysis\data\clean\v2\cleaned_job_descriptions_internships_v2.csv", index=False)

# %%
df_junior = df[df['type'].eq('Junior')]
df_junior.head(10)
# Out:
#     Unnamed: 0  id          role    type  \
# 4            4   5   AI Engineer  Junior
# 5            5   6   AI Engineer  Junior
# 7            7   8   AI Engineer  Junior
# 13          13  14   AI Engineer  Junior
# 14          14  15   AI Engineer  Junior
# 15          15  16   AI Engineer  Junior
# 16          16  17  AI Developer  Junior
# 17          17  18   AI Engineer  Junior
# 20          20  21   AI Engineer  Junior
# 23          23  24   AI Engineer  Junior
#
#                                              job_desc  year qualification  \
# 4   AI/ML models, Python, Core ML concepts, ML fra...  2026     Bachelors
# 5   4–5 years of proven development experience in ...  2026     Bachelors
# 7   Proficiency in C/C++ and python programming\r\...  2026     Bachelors
# 13  Basic understanding of AI, Machine Learning, o...  2026     Bachelors
# 14  Docker / Containerization\r\nAWS / Azure / GCP...  2026     Bachelors
# ...

# %%
df_junior.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 214 entries, 4 to 745
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     214 non-null    int64
#  1   id             214 non-null    int64
#  2   role           214 non-null    str
#  3   type           214 non-null    str
#  4   job_desc       214 non-null    str
#  5   year           214 non-null    int64
#  6   qualification  214 non-null    str
#  7   experience     214 non-null    str
#  8   tech_skills    214 non-null    str
#  9   soft_skills    214 non-null    str
# dtypes: int64(3), str(7)
# memory usage: 18.4 KB

# %%
df_junior.to_csv(r"C:\Portfolio-Projects\Job-Description-Analysis\data\clean\v2\cleaned_job_descriptions_junior_v2.csv", index=False)

# %%
df_senior = df[df['type'].eq('Senior')]
df_senior.head(15)
# Out:
#     Unnamed: 0  id          role    type  \
# 3            3   4   AI Engineer  Senior
# 6            6   7   AI Engineer  Senior
# 10          10  11   AI Engineer  Senior
# 11          11  12   AI Engineer  Senior
# 18          18  19   AI Engineer  Senior
# 19          19  20   AI Engineer  Senior
# 21          21  22  AI Developer  Senior
# 22          22  23   AI Engineer  Senior
# 28          28  29  AI Developer  Senior
# 29          29  30  AI Developer  Senior
# 30          30  31  AI Developer  Senior
# 31          31  32   AI Engineer  Senior
# 39          39  40   AI Engineer  Senior
# 41          41  42   AI Engineer  Senior
# 42          42  43   AI Engineer  Senior
#
#                                              job_desc  year  \
# 3   6+ years full-stack software engineering exper...  2026
# 6   5-10 years overall experience\r\n3+ years of h...  2026
# 10  4–6 years of experience in Data Science / Mach...  2026
# ...

# %%
df_senior.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 432 entries, 3 to 746
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     432 non-null    int64
#  1   id             432 non-null    int64
#  2   role           432 non-null    str
#  3   type           432 non-null    str
#  4   job_desc       432 non-null    str
#  5   year           432 non-null    int64
#  6   qualification  432 non-null    str
#  7   experience     432 non-null    str
#  8   tech_skills    432 non-null    str
#  9   soft_skills    432 non-null    str
# dtypes: int64(3), str(7)
# memory usage: 37.1 KB

# %%
df_senior.to_csv(r"C:\Portfolio-Projects\Job-Description-Analysis\data\clean\v2\cleaned_job_descriptions_senior_v2.csv", index=False)

# %%
df_dev = df[df['role'].eq('AI Developer')]
df_dev.head(10)
# Out:
#     Unnamed: 0  id          role        type  \
# 12          12  13  AI Developer  Internship
# 16          16  17  AI Developer      Junior
# 21          21  22  AI Developer      Senior
# 28          28  29  AI Developer      Senior
# 29          29  30  AI Developer      Senior
# 30          30  31  AI Developer      Senior
# 32          32  33  AI Developer      Junior
# 46          46  47  AI Developer  Internship
# 47          47  48  AI Developer  Internship
# 48          48  49  AI Developer  Internship
#
#                                              job_desc  year  qualification  \
# 12  Basic to intermediate Python programming skill...  2026      Bachelors
# 16  Strong Python programming\r\nExperience with F...  2026      Bachelors
# 21  Core Software Engineering (Required)\r\nStrong...  2026  Not Specified
# 28  trong hands-on experience in Python backend de...  2026      Bachelors
# 29  To qualify for the role you must have B.E/ B.T...  2026        Masters
# ...
